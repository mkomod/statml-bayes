# %% [markdown]
# ## Contrastive learning: learning a Gaussian mixture pdf using a neural net

# %%
import numpy as np
from scipy.stats import norm, multivariate_normal, rv_continuous
from sklearn.model_selection import train_test_split

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')

# %% [markdown]
# ### Data - setting up distributions

# %% [markdown]
# This is our Gaussian mixture class.
#
# It's not implemented very robustly but is enough to generate samples and compare the neural net to its pdf p.

# %%
class Mixture(rv_continuous):
    def __init__(self, *args):
        self.distns = args
        super().__init__()
        
    def pdf(self, x):
        return np.mean([d.pdf(x) for d in self.distns])
    
    def rvs(self, size=1):
        samples = [d.rvs(size=size) for d in self.distns]
        indices = np.random.randint(low=0, high=len(self.distns), size=size)
        return np.array([samples[indices[i]][i] for i in range(size)])

# %% [markdown]
# We use one component with mean (1,1)^T, the other with (-1,-1)^T

# %%
mixture_component_1 = multivariate_normal([1, 1], [[0.25, 0], [0, 0.25]])
mixture_component_2 = multivariate_normal([-1, -1], [[0.25, 0], [0, 0.25]])
true_mixture = Mixture(mixture_component_1, mixture_component_2)

# %% [markdown]
# Let's visualise the pdf...

# %%
x1, x2 = np.mgrid[-2:2:0.01, -2:2:0.01]
pos = np.dstack((x1, x2))
_ = plt.contourf(x1, x2, np.array([[true_mixture.pdf(x) for x in p] for p in pos]))

# %% [markdown]
# ...and check it lines up with samples

# %%
x1, x2 = true_mixture.rvs(size=10000).T
_ = sns.kdeplot(x=x1, y=x2, shade=True)

# %% [markdown]
# We use a standard multivariate normal for the noise, and again visualise the pdf and some samples:

# %%
noise = multivariate_normal([0,0], [[1, 0], [0, 1]])

# %%
# Visualising the noise pdf
x1, x2 = np.mgrid[-2:2:0.01, -2:2:0.01]
pos = np.dstack((x1, x2))
_ = plt.contourf(x1, x2, np.array([[noise.pdf(x) for x in p] for p in pos]))

# %%
# Visualising our noise samples
x1, x2 = noise.rvs(size=10000).T
_ = sns.kdeplot(x=x1, y=x2, shade=True)

# %% [markdown]
# ### Data - generation

# %%
N = 100000

# %%
X = np.concatenate([
    true_mixture.rvs(size=N),
    noise.rvs(size=N)
])
y = np.concatenate([
    np.ones(N),
    np.zeros(N)
])

# %%
# Use this if you don't care about having a train/test split - we'll use one for validation
# permutation = np.random.permutation(20000)
# X = X[permutation]
# y = y[permutation]
# y[:10]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
y_test
# Out:
# array([1., 0., 0., ..., 0., 1., 1.])

# %% [markdown]
# ### Model - construction

# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# This time we use a bigger network with two hidden layers.

# %%
model = Sequential()
model.add(Dense(20, input_dim=2, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.predict(X_train[0:5])
# Out:
# array([[0.4139811 ],
#        [0.38664767],
#        [0.44877553],
#        [0.42573914],
#        [0.46204093]], dtype=float32)

# %%
history = model.fit(
    X_train,
    y_train,
    batch_size=64,
    epochs=10,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/10
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.4838 - accuracy: 0.7725 - val_loss: 0.4668 - val_accuracy: 0.7849
# Epoch 2/10
# 2500/2500 [==============================] - 2s 975us/step - loss: 0.4654 - accuracy: 0.7849 - val_loss: 0.4669 - val_accuracy: 0.7829
# Epoch 3/10
# 2500/2500 [==============================] - 2s 970us/step - loss: 0.4618 - accuracy: 0.7858 - val_loss: 0.4596 - val_accuracy: 0.7886
# Epoch 4/10
# 2500/2500 [==============================] - 2s 960us/step - loss: 0.4605 - accuracy: 0.7865 - val_loss: 0.4590 - val_accuracy: 0.7883
# Epoch 5/10
# 2500/2500 [==============================] - 2s 964us/step - loss: 0.4601 - accuracy: 0.7865 - val_loss: 0.4593 - val_accuracy: 0.7880
# Epoch 6/10
# 2500/2500 [==============================] - 2s 960us/step - loss: 0.4600 - accuracy: 0.7864 - val_loss: 0.4580 - val_accuracy: 0.7891
# Epoch 7/10
# 2500/2500 [==============================] - 2s 964us/step - loss: 0.4597 - accuracy: 0.7867 - val_loss: 0.4575 - val_accuracy: 0.7890
# Epoch 8/10
# 2500/2500 [==============================] - 2s 967us/step - loss: 0.4596 - accuracy: 0.7870 - val_loss: 0.4588 - val_accuracy: 0.7889
# Epoch 9/10
# 2500/2500 [==============================] - 2s 967us/step - loss: 0.4597 - accuracy: 0.7866 - val_loss: 0.4597 - val_accuracy: 0.7876
# Epoch 10/10
# 2500/2500 [==============================] - 2s 965us/step - loss: 0.4595 - accuracy: 0.7869 - val_loss: 0.4584 - val_accuracy: 0.7887

# %%
plt.plot(history.history['val_accuracy'], label='Accuracy')
plt.plot(history.history['val_loss'], label='Loss')
plt.legend()

# %% [markdown]
# ### Results

# %% [markdown]
# Let's plot contour maps to check out the densities.

# %%
x1, x2 = np.mgrid[-2:2:0.01, -2:2:0.01]
pos = np.dstack((x1, x2))

# %% [markdown]
# First let's recall our true pdf p:

# %%
_ = plt.contourf(x1, x2, np.array([[true_mixture.pdf(x) for x in p] for p in pos]))

# %% [markdown]
# Now let's solve for our approximation to p:

# %% [markdown]
# $d = \frac{p}{p + q} \implies p = \frac{qd}{1 - d}$

# %%
d = model.predict(pos).reshape(400,400)
q = noise.pdf(pos)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 2) for input Tensor("dense_input:0", shape=(None, 2), dtype=float32), but it was called on an input with incompatible shape (None, 400, 2).

# %%
p = q * d / (1 - d)

# %%
_ = plt.contourf(x1, x2, p)

# %% [markdown]
# The components are nicer and more round than the single-layer model previously.
